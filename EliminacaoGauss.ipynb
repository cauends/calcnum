# %%
import numpy as np

# %%
from numpy import linalg

# %%
A = np.array([[0.2345,0.6793,0.0145,1.3315, 3.032], [2.2360,1.9861,-1.7724,2.0315, 2.135], [1.7724,-7.3324,5.1961,-2.8284, 1.015],
[1.4142,1.7320,-5.3173, 5.6785, 2.101]], dtype='double')

# %%
print(A)
# Out:
# [[ 0.2345  0.6793  0.0145  1.3315  3.032 ]
#  [ 2.236   1.9861 -1.7724  2.0315  2.135 ]
#  [ 1.7724 -7.3324  5.1961 -2.8284  1.015 ]
#  [ 1.4142  1.732  -5.3173  5.6785  2.101 ]]

# %%
A[1,:] = A[1,:] - (A[1,0]/A[0,0])*A[0,:]
A[2,:] =  A[2,:] - (A[2,0]/A[0,0])*A[0,:]
A[3,:] = A[3,:] - (A[3,0]/A[0,0])*A[0,:]

# %%
print(A)
# Out:
# [[ 2.34500000e-01  6.79300000e-01  1.45000000e-02  1.33150000e+00
#    3.03200000e+00]
#  [ 0.00000000e+00 -4.49114861e+00 -1.91066013e+00 -1.06645938e+01
#   -2.67756695e+01]
#  [ 0.00000000e+00 -1.24666913e+01  5.08650597e+00 -1.28921552e+01
#   -2.19014896e+01]
#  [ 0.00000000e+00 -2.36465697e+00 -5.40474520e+00 -2.35138188e+00
#   -1.61840934e+01]]

# %%
A[2,:] = A[2,:] - (A[2,1]/A[1,1])*A[1,:]
A[3,:] = A[3,:] - (A[3,1]/A[1,1])*A[1,:]
print(A)
# Out:
# [[ 2.34500000e-01  6.79300000e-01  1.45000000e-02  1.33150000e+00
#    3.03200000e+00]
#  [ 0.00000000e+00 -4.49114861e+00 -1.91066013e+00 -1.06645938e+01
#   -2.67756695e+01]
#  [ 0.00000000e+00  1.77635684e-15  1.03901849e+01  1.67110066e+01
#    5.24233739e+01]
#  [ 0.00000000e+00  0.00000000e+00 -4.39875404e+00  3.26368640e+00
#   -2.08630259e+00]]

# %%
A = [[ 2.34500000e-01,  6.79300000e-01,  1.45000000e-02,  1.33150000e+00,
   3.03200000e+00],
 [ 0.00000000e+00, -4.49114861e+00, -1.91066013e+00, -1.06645938e+01,
  -2.67756695e+01],
 [ 0.00000000e+00,  0,  1.03901849e+01,  1.67110066e+01,
   5.24233739e+01],
 [ 0.00000000e+00,  0.00000000e+00, -4.39875404e+00,  3.26368640e+00,
  -2.08630259e+00]]
print(A)
# Out:
# [[0.2345, 0.6793, 0.0145, 1.3315, 3.032], [0.0, -4.49114861, -1.91066013, -10.6645938, -26.7756695], [0.0, 0, 10.3901849, 16.7110066, 52.4233739], [0.0, 0.0, -4.39875404, 3.2636864, -2.08630259]]

# %%
A[3,:] = A[3,:] - (A[3,2]/A[2,2])*A[2,:]

# %%
print(A)
# Out:
# [[ 2.34500000e-01  6.79300000e-01  1.45000000e-02  1.33150000e+00
#    3.03200000e+00]
#  [ 0.00000000e+00 -4.49114861e+00 -1.91066013e+00 -1.06645938e+01
#   -2.67756695e+01]
#  [ 0.00000000e+00  1.77635684e-15  1.03901849e+01  1.67110066e+01
#    5.24233739e+01]
#  [ 0.00000000e+00  7.52032513e-16  0.00000000e+00  1.03384025e+01
#    2.01074823e+01]]

# %%
a = np.array([[ 2.34500000e-01,  6.79300000e-01,  1.45000000e-02,  1.33150000e+00,
   3.03200000e+00],
 [ 0.00000000e+00, -4.49114861e+00, -1.91066013e+00, -1.06645938e+01,
  -2.67756695e+01],
 [ 0.00000000e+00,  0,  1.03901849e+01,  1.67110066e+01,
   5.24233739e+01],
 [ 0.00000000e+00,  0,  0.00000000e+00,  1.03384025e+01,
   2.01074823e+01]], dtype='double')

# %%
print(a)
# Out:
# [[ 2.34500000e-01  6.79300000e-01  1.45000000e-02  1.33150000e+00
#    3.03200000e+00]
#  [ 0.00000000e+00 -4.49114861e+00 -1.91066013e+00 -1.06645938e+01
#   -2.67756695e+01]
#  [ 0.00000000e+00  0.00000000e+00  1.03901849e+01  1.67110066e+01
#    5.24233739e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.03384025e+01
#    2.01074823e+01]]

# %%
H = [[ 2.34500000e-01,  6.79300000e-01,  1.45000000e-02,  1.33150000e+00,
   3.03200000e+00],
 [ 0.00000000e+00, -4.49114861e+00, -1.91066013e+00, -1.06645938e+01,
  -2.67756695e+01],
 [ 0.00000000e+00,  0,  1.03901849e+01,  1.67110066e+01,
   5.24233739e+01],
 [ 0.00000000e+00,  0,  0.00000000e+00,  1.03384025e+01,
   2.01074823e+01]]

# %%
print(H)
# Out:
# [[0.2345, 0.6793, 0.0145, 1.3315, 3.032], [0.0, -4.49114861, -1.91066013, -10.6645938, -26.7756695], [0.0, 0, 10.3901849, 16.7110066, 52.4233739], [0.0, 0, 0.0, 10.3384025, 20.1074823]]
